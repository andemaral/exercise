# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
df=pd.read_csv('Interview Exercise Nick2.csv',parse_dates=['Start Date','End Date'])
df.dtypes
# Out:
# Start Date    datetime64[ns]
# End Date      datetime64[ns]
# Id                     int64
# dtype: object

# %%
df.shape
# Out:
# (1399, 3)

# %%
df['Id']=df['Id'].astype('object')
df.dtypes
df['Duration']=df['End Date']-df['Start Date']

# %%
df['Duration Years']=df['Duration']/pd.to_timedelta(1,unit="Y")
df['Duration Months']=df['Duration']//pd.to_timedelta(1,unit="M")
df.head(5)
print(df.shape)
# Out:
# (1399, 6)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:208: FutureWarning: M and Y units are deprecated and will be removed in a future version.
#   return func(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\tools\timedeltas.py:134: FutureWarning: M and Y units are deprecated and will be removed in a future version.
#   result = Timedelta(r, unit)

# %%
df.head(5)
# Out:
#   Start Date   End Date    Id  Duration  Duration Years  Duration Months
# 0 2014-02-14 2020-01-01     1 2147 days        5.878286               70
# 1 2014-07-01 2016-08-01     1  762 days        2.086285               25
# 2 2015-05-23 2015-12-01     1  192 days        0.525678                6
# 3 2016-10-04 2017-01-01  1011   89 days        0.243674                2
# 4 2014-04-25 2017-11-04   794 1289 days        3.529162               42

# %%
from datetime import datetime
 
given_date = datetime.today().date()
 
first_day_of_month = given_date.replace(day=1)

# %%
print(min(df['Start Date']))
print(max(df['End Date']))
# Out:
# 2014-02-14 00:00:00
# 2020-01-01 00:00:00

# %%
import datetime
import time

def mkDateTime(dateString,strFormat="%Y-%m-%d"):
    # Expects "YYYY-MM-DD" string
    # returns a datetime object
    eSeconds = time.mktime(time.strptime(dateString,strFormat))
    return datetime.datetime.fromtimestamp(eSeconds)

def formatDate(dtDateTime,strFormat="%Y-%m-%d"):
    # format a datetime object as YYYY-MM-DD string and return
    return dtDateTime.strftime(strFormat)

def mkFirstOfMonth2(dtDateTime):
    #what is the first day of the current month
    ddays = int(dtDateTime.strftime("%d"))-1 #days to subtract to get to the 1st
    delta = datetime.timedelta(days= ddays)  #create a delta datetime object
    return dtDateTime - delta                #Subtract delta and return

def mkFirstOfMonth(dtDateTime):
    #what is the first day of the current month
    #format the year and month + 01 for the current datetime, then form it back
    #into a datetime object
    return mkDateTime(formatDate(dtDateTime,"%Y-%m-01"))

def mkLastOfMonth(dtDateTime):
    dYear = dtDateTime.strftime("%Y")        #get the year
    dMonth = str(int(dtDateTime.strftime("%m"))%12+1)#get next month, watch rollover
    dDay = "1"                               #first day of next month
    nextMonth = mkDateTime("%s-%s-%s"%(dYear,dMonth,dDay))#make a datetime obj for 1st of next month
    delta = datetime.timedelta(seconds=1)    #create a delta of 1 second
    return nextMonth - delta                 #subtract from nextMonth and return

# %%
#for x in df['Start Date'].astype(object):
df['start month']=df['Start Date'].astype(object).apply(mkFirstOfMonth)

# %%
df.head(5)
df.shape
# Out:
# (1399, 7)

# %%
from datetime import timedelta 
def check(start,end):  
    Result = []
    while start <= end:
        Result.append(start)
        start = start + timedelta(days=1)
    return Result

# %%
df['ActivityDate'] = df.apply(lambda row: check(row['Start Date'],row['End Date']),axis=1)
df = df.explode('ActivityDate')

# %%
df.shape
# Out:
# (752048, 8)

# %%
df.dtypes
# Out:
# Start Date          datetime64[ns]
# End Date            datetime64[ns]
# Id                          object
# Duration           timedelta64[ns]
# Duration Years             float64
# Duration Months              int64
# start month         datetime64[ns]
# ActivityDate        datetime64[ns]
# dtype: object

# %%
df.sort_values(by='ActivityDate',ascending=True)
df['ActivityDateDif']=df['ActivityDate']-df['Start Date']
df['ActivityDateDifMonth']=df['ActivityDateDif']/pd.to_timedelta(1,unit="M")
df['ActivityDateDifYear']=df['ActivityDateDif']/pd.to_timedelta(1,unit="Y")
#df['Job Ended']=df['ActivityDateDifMonth']>=df['Duration Months']

# %%
#df['date'] = pd.to_datetime(df['ActivityDate'])
df['day'] = df['ActivityDate'].apply(lambda x: x.day)

# %%
def counter_job(end_date):
    counter=[]
    if ((df3[end_date]-df3['ActivityDate'])/pd.to_timedelta(1,unit="M"))<0:
        counter=counter+1
    else:
        counter=counter
    return counter

# %%
df2.head(71)
# Out:
#    Start Date   End Date Id  Duration  Duration Years  Duration Months  \
# 0  2014-02-14 2020-01-01  1 2147 days        5.878286               70
# 0  2014-02-14 2020-01-01  1 2147 days        5.878286               70
# 0  2014-02-14 2020-01-01  1 2147 days        5.878286               70
# 0  2014-02-14 2020-01-01  1 2147 days        5.878286               70
# 0  2014-02-14 2020-01-01  1 2147 days        5.878286               70
# ..        ...        ... ..       ...             ...              ...
# 0  2014-02-14 2020-01-01  1 2147 days        5.878286               70
# 0  2014-02-14 2020-01-01  1 2147 days        5.878286               70
# 0  2014-02-14 2020-01-01  1 2147 days        5.878286               70
# 0  2014-02-14 2020-01-01  1 2147 days        5.878286               70
# 0  2014-02-14 2020-01-01  1 2147 days        5.878286               70
#
#    start month ActivityDate ActivityDateDif  ActivityDateDifMonth  \
# ...

# %%
df['Job Ended']=df['End Date']<=df['ActivityDate']

# %%
df.head(72)
# Out:
#    Start Date   End Date Id  Duration  Duration Years  Duration Months  \
# 0  2014-02-14 2020-01-01  1 2147 days        5.878286               70
# 0  2014-02-14 2020-01-01  1 2147 days        5.878286               70
# 0  2014-02-14 2020-01-01  1 2147 days        5.878286               70
# 0  2014-02-14 2020-01-01  1 2147 days        5.878286               70
# 0  2014-02-14 2020-01-01  1 2147 days        5.878286               70
# ..        ...        ... ..       ...             ...              ...
# 0  2014-02-14 2020-01-01  1 2147 days        5.878286               70
# 0  2014-02-14 2020-01-01  1 2147 days        5.878286               70
# 0  2014-02-14 2020-01-01  1 2147 days        5.878286               70
# 0  2014-02-14 2020-01-01  1 2147 days        5.878286               70
# 1  2014-07-01 2016-08-01  1  762 days        2.086285               25
#
#    start month ActivityDate ActivityDateDif  ActivityDateDifMonth  \
# ...

# %%
df['counter_true']=

# %%
df.drop(columns='cumsum',inplace=True)

# %%
df=df[df['day']==1]
df['completed']=df['ActivityDateDif']*df['Job Ended']

# %%
df['completed']=df['completed']/pd.to_timedelta(1,unit="M")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:208: FutureWarning: M and Y units are deprecated and will be removed in a future version.
#   return func(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\tools\timedeltas.py:134: FutureWarning: M and Y units are deprecated and will be removed in a future version.
#   result = Timedelta(r, unit)

# %%
# making list of values   
# making series from list 
series =df['Job Ended']
#print(series)  
# calling method 
cumsum = round(series.cumsum(),4) 
df['cumsum']=cumsum
series_completed=df['completed']
cumsum2=round(series_completed.cumsum(),4)
df['cumsum_completed']=cumsum2

# %%
df['avg_completed_duration']=df['cumsum_completed']/df['cumsum']

# %%
#df.replace(0,np.nan)[df['Id']==1].groupby(['ActivityDate',])['completed'].agg({'completed': lambda x: x.mean(skipna=True)}).sort_values(by='ActivityDate',ascending=True).head(50)
#df.groupby['Id','ActivityDate'][]

# %%
df['avg_completed_duration_year']=df['avg_completed_duration']/12

# %%
df.sort_values(by='ActivityDate')
report=df[['ActivityDate','Start Date', 'End Date', 'Id',
       'Duration Months','ActivityDateDifYear','completed','avg_completed_duration_year']]
report.rename(columns={'ActivityDateDifMonth':'Cumul Year Experience','avg_completed_duration_year':'Avg Completed Duration'},inplace=True)
# Out:
#      ActivityDate Start Date   End Date   Id  Duration Months  \
# 0      2014-03-01 2014-02-14 2020-01-01    1               70
# 0      2014-04-01 2014-02-14 2020-01-01    1               70
# 0      2014-05-01 2014-02-14 2020-01-01    1               70
# 0      2014-06-01 2014-02-14 2020-01-01    1               70
# 0      2014-07-01 2014-02-14 2020-01-01    1               70
# ...           ...        ...        ...  ...              ...
# 1398   2018-10-01 2017-01-01 2019-02-26  896               25
# 1398   2018-11-01 2017-01-01 2019-02-26  896               25
# 1398   2018-12-01 2017-01-01 2019-02-26  896               25
# 1398   2019-01-01 2017-01-01 2019-02-26  896               25
# 1398   2019-02-01 2017-01-01 2019-02-26  896               25
#
#       ActivityDateDifYear  completed  Avg Completed Duration
# 0                0.041069        0.0                     NaN
# 0                0.125944        0.0                     NaN
# ...

# %%
report.to_csv(r'C:\Users\Mankarov\Data Science Digital House\Modulo 2 EDA & Pandas\Clase 5 Data Wrangling y DataTimestamp\report.csv')
# Out:
#    ActivityDate Start Date   End Date Id  Duration Months  \
# 0    2014-03-01 2014-02-14 2020-01-01  1               70
# 0    2014-04-01 2014-02-14 2020-01-01  1               70
# 0    2014-05-01 2014-02-14 2020-01-01  1               70
# 0    2014-06-01 2014-02-14 2020-01-01  1               70
# 0    2014-07-01 2014-02-14 2020-01-01  1               70
# ..          ...        ...        ... ..              ...
# 0    2019-11-01 2014-02-14 2020-01-01  1               70
# 0    2019-12-01 2014-02-14 2020-01-01  1               70
# 0    2020-01-01 2014-02-14 2020-01-01  1               70
# 1    2014-07-01 2014-07-01 2016-08-01  1               25
# 1    2014-08-01 2014-07-01 2016-08-01  1               25
#
#     ActivityDateDifMonth  completed  avg_completed_duration
# 0               0.492823   0.000000                     NaN
# 0               1.511325   0.000000                     NaN
# 0               2.496971   0.000000                     NaN
# ...

# %%
#df[df['Job Ended']==False].sort_values(by='ActivityDate',ascending=False)
#df['Job Completed Duration']=df['Duration Months']*df['Job Ended']

# %%
#df['Job Ended']=df['ActivityDateDifMonth']>=df['Duration Months']

# %%
#df['Job Ended Average']=df[df['Job Ended']==True].groupby('Id')['Job Completed Duration'].mean()

# %%
#df['Job Ended Average']=df['Job Ended Average'].replace(np.nan,0)

# %%
#df[(df['Id']==8)].sort_values(by='End Date',ascending=True)

# %%
report=df[['ActivityDate','Start Date', 'End Date', 'Id','ActivityDateDif',
       'ActivityDateDifMonth', 'ActivityDateDifYear']]

# %%
report.columns

# %%
report['ActivityDateDifMonth']=report['ActivityDateDifMonth'].round(2)
report['ActivityDateDifYear']=report['ActivityDateDifYear'].round(2)

# %%
report.groupby(['ActivityDate','Id'])[['ActivityDateDifMonth','ActivityDateDifYear']].sum()

# %%
df3=report.groupby(['ActivityDate','Id'])[['ActivityDateDifMonth','ActivityDateDifYear']].sum().reset_index()

# %%
df3

# %%
df3=df3.set_index('ActivityDate')

# %%
df3.rename(columns={'ActivityDateDifMonth':'Monthly Accumulated Duration','ActivityDateDifYear':'Yearly Accumulated Duration'},inplace=True)

# %%
print(df3)

# %%
df3.to_csv(r'C:\Users\Mankarov\Data Science Digital House\Modulo 2 EDA & Pandas\Clase 5 Data Wrangling y DataTimestamp\summary.csv')
